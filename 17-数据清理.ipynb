# %%
import pandas as pd
# 创建一个示例 DataFrame
data = {
    'Column1': [1, None, 3, None],
    'Column2': [4, None, None, None],
    'Column3': [7, 8, 9, None],
    'Column4': [7, 8, 9, None]
}
df = pd.DataFrame(data)
print("原始 DataFrame:")
df
# Out:
# 原始 DataFrame:
#    Column1  Column2  Column3  Column4
# 0      1.0      4.0      7.0      7.0
# 1      NaN      NaN      8.0      8.0
# 2      3.0      NaN      9.0      9.0
# 3      NaN      NaN      NaN      NaN

# %%
# 列出所有空白值
print("列出所有空白值：")
df[df.isnull().T.any()]
# Out:
# 列出所有空白值：
#    Column1  Column2  Column3  Column4
# 1      NaN      NaN      8.0      8.0
# 2      3.0      NaN      9.0      9.0
# 3      NaN      NaN      NaN      NaN

# %%
# 删除所有列都是空值的行
df.dropna(how='all', inplace=True)

# 打印处理后的 DataFrame
df
# Out:
#    Column1  Column2  Column3  Column4
# 0      1.0      4.0      7.0      7.0
# 1      NaN      NaN      8.0      8.0
# 2      3.0      NaN      9.0      9.0

# %%
# 将 NaN 值替换为 0
df_filled = df.fillna('空白值')
df_filled
# Out:
#   Column1 Column2  Column3  Column4
# 0     1.0     4.0      7.0      7.0
# 1     空白值     空白值      8.0      8.0
# 2     3.0     空白值      9.0      9.0

# %%
import mytools

# %%
数据表 = mytools.读取SPSS数据文件(R'date\identity.sav',True)

# %%
数据表[数据表.isnull().T.any()]
# Out:
#       问卷编号   调查员    民族 政治面貌   年级 您觉得自己是个典型的中国人吗 与世界其他国家的人相比中国人有自己的特点吗    v1  \
# 78     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 79     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 80     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 81     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 82     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 83     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 84     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 85     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 86     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 87     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 88     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 89     NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 121  870.0  古丽娜孜   NaN  NaN  NaN            NaN                   NaN   NaN
# 124  793.0   李金桃   NaN  NaN  NaN            NaN                   NaN   NaN
# 133  802.0   张玉梅    汉族   团员   大三            一般般                  较有特点  完全同意
# 158  227.0    吴桐    汉族   团员   大一            可以算                  较有特点  完全同意
# 271    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 283    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 295    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 368    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 369    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 409  891.0   张璐婷    回族   团员   大二            可以算                 非常有特点  完全同意
# 479    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 480    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 481    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 482    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 483    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 484    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 485    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 486    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 487    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 488    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 587    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 617    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 689    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 741   13.0   黄明军    汉族   团员   大一            完全是                  较有特点  有点同意
# 749   21.0   黄明军    汉族   群众  NaN            不太算                   一般般   不同意
# 750   22.0   黄明军    汉族   群众   大三            一般般                   一般般  有点同意
# 751   23.0   黄明军  维吾尔族   党员   大二            不太算                   NaN   不同意
# 753   25.0   黄明军    汉族   团员   大三            完全是                  较无特点  完全同意
# 812    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 813    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 814    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 870    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 871    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 872    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 873    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
# 874    NaN         NaN  NaN  NaN            NaN                   NaN   NaN
#
#        v2     v3  ...   会隐瞒身份吗  会打多少分    国歌升起   世博会     中国传统文化   发展信心  \
# 78    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 79    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 80    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 81    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 82    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 83    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 84    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 85    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 86    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 87    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 88    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 89    NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 121   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 124   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 133  完全同意     同意  ...     绝对不会  八十到一百    比较激动  感到自豪       比较肯定  担忧不好说
# 158  完全同意   有点同意  ...     绝对不会  八十到一百     没感觉   NaN  富有内涵，意义深刻   很有信心
# 271   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 283   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 295   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 368   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 369   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 409  完全同意   完全同意  ...      可能会  六十到八十     NaN  感到自豪  富有内涵，意义深刻   很有信心
# 479   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 480   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 481   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 482   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 483   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 484   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 485   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 486   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 487   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 488   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 587   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 617   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 689   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 741    同意  完全不同意  ...  也许会也许不会   零到二十      一般   比较好       比较肯定  担忧不好说
# 749   不同意   有点同意  ...      可能会  四十到六十     没感觉    一般  富有内涵，意义深刻    没信心
# 750  有点同意   有点同意  ...  也许会也许不会  四十到六十    比较激动    一般   古板，跟不上潮流    没信心
# 751   不同意    不同意  ...    很可能不会  四十到六十     没感觉   没感觉   古板，跟不上潮流  担忧不好说
# 753  完全同意   完全同意  ...     绝对不会  四十到六十    比较激动   比较好       比较肯定    NaN
# 812   NaN    NaN  ...    很可能不会  四十到六十      一般   比较好       比较肯定  担忧不好说
# 813   NaN    NaN  ...      可能会  四十到六十  感到非常激动   比较好  富有内涵，意义深刻  担忧不好说
# 814   NaN    NaN  ...      可能会  六十到八十  感到非常激动  感到自豪  富有内涵，意义深刻   很有信心
# 870   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 871   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 872   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 873   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
# 874   NaN    NaN  ...      NaN    NaN     NaN   NaN        NaN    NaN
#
#     你会为中国运动员呐喊助威 遇到灾难时中国人应该伸出援手 你愿意加入其他国籍吗 中国人要为祖国统一奋斗吗
# 78           NaN            NaN        NaN          NaN
# 79           NaN            NaN        NaN          NaN
# 80           NaN            NaN        NaN          NaN
# 81           NaN            NaN        NaN          NaN
# 82           NaN            NaN        NaN          NaN
# 83           NaN            NaN        NaN          NaN
# 84           NaN            NaN        NaN          NaN
# 85           NaN            NaN        NaN          NaN
# 86           NaN            NaN        NaN          NaN
# 87           NaN            NaN        NaN          NaN
# 88           NaN            NaN        NaN          NaN
# 89           NaN            NaN        NaN          NaN
# 121          NaN            NaN        NaN          NaN
# 124          NaN            NaN        NaN          NaN
# 133      大多数情况下会             赞同      做外籍华人          NaN
# 158      大多数情况下会             赞同      做外籍华人          很赞同
# 271          NaN            NaN        NaN          NaN
# 283          NaN            NaN        NaN          NaN
# 295          NaN            NaN        NaN          NaN
# 368          NaN            NaN        NaN          NaN
# 369          NaN            NaN        NaN          NaN
# 409          肯定会            很赞同      做外籍华人          很赞同
# 479          NaN            NaN        NaN          NaN
# 480          NaN            NaN        NaN          NaN
# 481          NaN            NaN        NaN          NaN
# 482          NaN            NaN        NaN          NaN
# 483          NaN            NaN        NaN          NaN
# 484          NaN            NaN        NaN          NaN
# 485          NaN            NaN        NaN          NaN
# 486          NaN            NaN        NaN          NaN
# 487          NaN            NaN        NaN          NaN
# 488          NaN            NaN        NaN          NaN
# 587          NaN            NaN        NaN          NaN
# 617          NaN            NaN        NaN          NaN
# 689          NaN            NaN        NaN          NaN
# 741          不一定            很赞同     毫不犹豫加入           赞同
# 749      大多数情况下会            不一定      做外籍华人          不赞同
# 750          不一定            不赞同      做外籍华人          不一定
# 751          不一定            不一定        不加入          不一定
# 753          NaN            NaN        NaN          NaN
# 812          不一定            不一定        不加入          不一定
# 813          肯定会            不一定         其他           赞同
# 814      大多数情况下会            不一定         其他           赞同
# 870          NaN            NaN        NaN          NaN
# 871          NaN            NaN        NaN          NaN
# 872          NaN            NaN        NaN          NaN
# 873          NaN            NaN        NaN          NaN
# 874          NaN            NaN        NaN          NaN
#
# [48 rows x 28 columns]

# %%
数据表.dropna(how="any",inplace=True)

# %%
数据表.年级.value_counts()
# Out:
# 年级
# 大一    305
# 大二    275
# 大三    169
# 大四     94
# 预科     14
# Name: count, dtype: int64

# %%
import pandas as pd

# 示例数据
data = {'value': [10, 12, 12, 13, 12, 11, 10, 29, 30, 11, 10, 100]}
df = pd.DataFrame(data)

# 计算均值和标准差
mean = df['value'].mean()
std = df['value'].std()
condition1 = (df['value'] < mean - 3 * std) | (df['value'] > mean + 3 * std)
# 识别异常值
outliers1 = df[condition1]
print('使用标准差判断的异常值为：',outliers1)

# 计算 IQR
Q1 = df['value'].quantile(0.25)
Q3 = df['value'].quantile(0.75)
IQR = Q3 - Q1

# 识别异常值
outliers2 = df[(df['value'] < Q1 - 1.5 * IQR) | (df['value'] > Q3 + 1.5 * IQR)]
print('使用IQR判断的异常值为：',outliers2)
# Out:
# 使用标准差判断的异常值为：     value
# 11    100
# 使用IQR判断的异常值为：     value
# 7      29
# 8      30
# 11    100

# %%
数据表.drop_duplicates(subset=['问卷编号'],keep='first',inplace=True)

# %%
import pandas as pd
df_movie = pd.read_csv(R'movie_data_cleaned.csv')
df_movie.dtypes
# Out:
# Unnamed: 0        int64
# average         float64
# country          object
# genre            object
# language         object
# release_date     object
# title            object
# votes           float64
# dtype: object

# %%
df_movie.dropna(how='any',inplace=True)
df_movie.astype({"title": "string", "votes": "int64",'genre':"category"}).dtypes
# Out:
# Unnamed: 0               int64
# average                float64
# country                 object
# genre                 category
# language                object
# release_date            object
# title           string[python]
# votes                    int64
# dtype: object

# %%
# 使用query
condition = '会以中国人自豪吗=="会" and 会隐瞒身份吗=="一定会"'

# 取得逻辑不一致数据的序号列表
result = 数据表.query(condition).index
print(result)
# 使用drop函数删除指定
数据表.drop(index=result,inplace=True)
# Out:
# Index([ 54,  70,  75, 161, 191, 236, 240, 251, 323, 338, 406, 428, 525, 576,
#        578, 579, 593, 595, 607, 665, 667, 679, 764, 770, 783, 784, 809, 839,
#        869, 899],
#       dtype='int64')
